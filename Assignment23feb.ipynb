# %% [markdown]
# ### Solution (1)

# %% [markdown]
# ####  Q1. Create a Pandas Series that contains the following data: 4, 8, 15, 16, 23, and 42. Then, print the series.

# %%
import pandas as pd

# %%
data = [4,8,15,16,23,42]

# %%
df = pd.Series(data)

# %%
df

# %% [markdown]
# ### Solution (2)

# %% [markdown]
# #### Q2. Create a variable of list type containing 10 elements in it, and apply pandas.Series function on the variable print it.

# %%
elements = ['anirudhra','yash','anshika','simran','prafull','yunus','sanket','hardika','chetna','deepa']

# %%
pd.Series(elements)
# Out:
# 0    anirudhra
# 1         yash
# 2      anshika
# 3       simran
# 4      prafull
# 5        yunus
# 6       sanket
# 7      hardika
# 8       chetna
# 9        deepa
# dtype: object

# %% [markdown]
# ### Solution (3)
#
# #### Q3. Create a Pandas DataFrame that contains the following data:

# %%
human_data = {
    "Name" : ['Alice','Bob','Claire'],
    "Age" : [25,30,27],
    "Gender" : ['Female','Male','Female']
}

# %%
df = pd.DataFrame(human_data)

# %%
df
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %% [markdown]
# ### Solution (4)
#
# #### Q4. What is ‘DataFrame’ in pandas and how is it different from pandas.series? Explain with an example.

# %% [markdown]
# * Panda is used to analyze the data.
# * It has functions for analyzing , cleaning, exploring, and manipulation data.
# * The name panda has a reference both "Panel Data" and "Python Data Analysis" and was created by wes mckinney in 2008.
# * It plays very important role in Data Science.
# * The reason behind using of this lib is playing with massive data.

# %% [markdown]
# **Series can contain only list with index whereas dataframe is available in form of tabular and it contains more than one series, or we can say that dataframe is collection of series.**

# %%
# Examples:
# series
fruits = ['Apple','Mango','Grapes','Kiwi','Watermelon']
pd.Series(fruits)
# Out:
# 0         Apple
# 1         Mango
# 2        Grapes
# 3          Kiwi
# 4    Watermelon
# dtype: object

# %%
# Dataframe
human_data = {
    "Name" : ['Alice','Bob','Claire'],
    "Age" : [25,30,27],
    "Gender" : ['Female','Male','Female'],
    "course" : ['DSA','DS','WEB DEV']
}

# %%
pd.DataFrame(human_data)
# Out:
#      Name  Age  Gender   course
# 0   Alice   25  Female      DSA
# 1     Bob   30    Male       DS
# 2  Claire   27  Female  WEB DEV

# %% [markdown]
# ### Solution (5)

# %% [markdown]
# #### Q5. What are some common functions you can use to manipulate data in a Pandas DataFrame? Can you give an example of when you might use one of these functions?

# %%
import pandas as pd

# %%
data = pd.read_csv("services.csv")

# %%
data
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
data.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
data.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
data.shape
# Out:
# (23, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       23 non-null     int64
#  1   location_id              23 non-null     int64
#  2   program_id               0 non-null      float64
#  3   accepted_payments        1 non-null      object
#  4   alternate_name           1 non-null      object
#  5   application_process      23 non-null     object
#  6   audience                 14 non-null     object
#  7   description              23 non-null     object
#  8   eligibility              21 non-null     object
#  9   email                    1 non-null      object
#  10  fees                     21 non-null     object
#  11  funding_sources          21 non-null     object
#  12  interpretation_services  1 non-null      object
#  13  keywords                 21 non-null     object
# ...

# %%
data.isna().sum()
# Out:
# id                          0
# location_id                 0
# program_id                 23
# accepted_payments          22
# alternate_name             22
# application_process         0
# audience                    9
# description                 0
# eligibility                 2
# email                      22
# fees                        2
# funding_sources             2
# interpretation_services    22
# keywords                    2
# languages                  22
# name                        0
# required_documents         22
# service_areas               2
# status                      0
# wait_time                   4
# website                    21
# taxonomy_ids               22
# dtype: int64

# %%
data.nunique()
# Out:
# id                         23
# location_id                22
# program_id                  0
# accepted_payments           1
# alternate_name              1
# application_process        20
# audience                   14
# description                23
# eligibility                16
# email                       1
# fees                       10
# funding_sources            14
# interpretation_services     1
# keywords                   18
# languages                   1
# name                       23
# required_documents          1
# service_areas              10
# status                      3
# wait_time                   7
# website                     1
# taxonomy_ids                1
# dtype: int64

# %%
data.application_process.value_counts()
# Out:
# Walk in or apply by phone or mail                                                                                                                                                                                                         2
# Apply by phone.                                                                                                                                                                                                                           2
# Walk in. Proof of California residency required to receive a library card.                                                                                                                                                                2
# Call for appointment. Referral from human service professional preferred for emergency assistance.                                                                                                                                        1
# ...

# %% [markdown]
# ### Solution (6)

# %% [markdown]
# #### Q6. Which of the following is mutable in nature Series, DataFrame, Panel?

# %% [markdown]
# Series is size immutable.
# Dataframe,Panel is mutable.

# %% [markdown]
# ### Solution (7)

# %% [markdown]
# #### Q7. Create a DataFrame using multiple Series. Explain with an example.

# %%
data1 = [4,8,15,16,23,42]
data2 = [2,3,46,67,67,45]

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(data1)

# %%
df2 = pd.DataFrame(data2)

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     0   0
# 0   4   2
# 1   8   3
# 2  15  46
# 3  16  67
# 4  23  67
# 5  42  45
